# %% [markdown]
# #### **라이브러리**

# %%
# !pip install dask
# Out:
# Requirement already satisfied: dask in /usr/local/lib/python3.10/dist-packages (2024.8.2)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dask) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask) (3.20.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask) (1.0.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report
import xgboost as xgb
import lightgbm as lgb
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, TensorDataset
import torch
import json
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
data = pd.read_csv('/content/drive/MyDrive/롤 데이터 분석/data/BRONZE_I_with_puuid_with_matchids_with_metadata.csv')
data
# Out:
#                                             summonerId    tier rank  \
# 0     P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 1     P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 2     P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 3     P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 4     P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# ...                                                ...     ...  ...
# 2455  EqN2ktKYrXn1twsHNu1y71_fQpFx3lcEKzLgIDV3-_XVxjEV  BRONZE    I
# 2456  EqN2ktKYrXn1twsHNu1y71_fQpFx3lcEKzLgIDV3-_XVxjEV  BRONZE    I
# 2457  EqN2ktKYrXn1twsHNu1y71_fQpFx3lcEKzLgIDV3-_XVxjEV  BRONZE    I
# 2458  EqN2ktKYrXn1twsHNu1y71_fQpFx3lcEKzLgIDV3-_XVxjEV  BRONZE    I
# 2459  EqN2ktKYrXn1twsHNu1y71_fQpFx3lcEKzLgIDV3-_XVxjEV  BRONZE    I
#
#       leaguePoints  wins  losses   winRatio  \
# 0               19    80      77  50.955414
# 1               19    80      77  50.955414
# 2               19    80      77  50.955414
# 3               19    80      77  50.955414
# 4               19    80      77  50.955414
# ...            ...   ...     ...        ...
# 2455            46    61      57  51.694915
# 2456            46    61      57  51.694915
# 2457            46    61      57  51.694915
# 2458            46    61      57  51.694915
# 2459            46    61      57  51.694915
#
#                                                   puuid        matchid  \
# 0     0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7159555521
# 1     0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7148630418
# 2     0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7148576264
# 3     0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7148570014
# 4     0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7142285759
# ...                                                 ...            ...
# 2455  kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gE...  KR_7206877673
# 2456  kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gE...  KR_7206835327
# 2457  kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gE...  KR_7206071352
# 2458  kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gE...  KR_7206026010
# 2459  kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gE...  KR_7205539746
#
#                                           metadata_json
# 0     {"metadata": {"dataVersion": "2", "matchId": "...
# 1     {"metadata": {"dataVersion": "2", "matchId": "...
# 2     {"metadata": {"dataVersion": "2", "matchId": "...
# 3     {"metadata": {"dataVersion": "2", "matchId": "...
# 4     {"metadata": {"dataVersion": "2", "matchId": "...
# ...                                                 ...
# 2455  {"metadata": {"dataVersion": "2", "matchId": "...
# 2456  {"metadata": {"dataVersion": "2", "matchId": "...
# 2457  {"metadata": {"dataVersion": "2", "matchId": "...
# 2458  {"metadata": {"dataVersion": "2", "matchId": "...
# 2459  {"metadata": {"dataVersion": "2", "matchId": "...
#
# [2460 rows x 10 columns]

# %%
data.columns
# Out:
# Index(['summonerId', 'tier', 'rank', 'leaguePoints', 'wins', 'losses',
#        'winRatio', 'puuid', 'matchid', 'metadata_json'],
#       dtype='object')

# %%
data['metadata_json'][0]
# Out:
# '{"metadata": {"dataVersion": "2", "matchId": "KR_7159555521", "participants": ["4yZN0Lk3BW4eojfEuXcUNwqaEArs-HJi_osvUQssrS-ExyKERLCWW8m5lypAGliR5v9pGITK76mo8A", "vl4GiFTMgeRPobclBLG_7b93_u4InNoMV5FGfDCBfcS1I2eMIxOCe0eLoLdjkY-D7T5pVaH9JlwpBQ", "8vZ-m-EqnLQIPcAsDKBkLbsKNBZ3TonCUhmMFchY7k9SVMoPcuWqqyEPHlescEeHH0LSVnTNv0KkRg", "ZFslqWKLKwyIXrqOoVswL4iQVwO3w7mywVoftpKAZFJTI_0gQut_7l2mHADxIhXlT0jBUKuuB2Dz-Q", "BsybsQAzD5w0VGZrZZu8an0XCLIsgH2RUNGFdZeU5HuBN6IGwZCW37HqESiyUUti-RANETNHhGrxmQ", "0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idGDska1rkBDpJxTxKZbyTro6EoYJgjY72g", "OpfgvHe93FoNubW7ILnANS2zQYxvhu76HAoxltzqGvOvZeDoqSa5SngMNtsMV_gxKM2GTz5PB9JQEw", "NNCWhdfqhNb3VA5ttSt66yT0rhDAuQdot8VJqUJ41UyUfEXJ_DoophHoozwb5fcMYT4MWdOeJq-9vg", "92KQIcAV89Dz_GXMNBVkLKUTSAuQShDUj8_F2kE1TM0MypiBZ9ypR8u0Ro72UPFO8TRtFrSwkqkKKw", "9r4fgmVpn_ztD9lRngFs_18c5ATBibP7HAMvtzVTCWdWSJLv8N1ZSjysBMuZD3rtm4tujAgbdJqJ6Q"]}, "info": {"endOfGameResult": "GameComplete", "gameCreation": 1721427880317, "gameDuration": 1702, "gameEndTimestamp": 1721429614262, "gameId": 7159555521, "gameMode": "CLASSIC", "gameName": "teambuilder-match-7159555521", "gameStartTimestamp": 1721427912125, "gameType": "MATCHED_GAME", "gameVersion": "14.14.602.3371", "mapId": 11, "participants": [{"allInPings": 0, "assistMePings": 1, "assists": 14, "baronKills": 1, "basicPings": 0, "bountyLevel": 3, "challenges": {"12AssistStreakCount": 0, "InfernalScalePickup": 0, "SWARM_DefeatAatrox": 0, "SWARM_DefeatBriar": 0, "SWARM_DefeatMiniBosses": 0, "SWARM_EvolveWeapon": 0, "SWARM_Have3Passives": 0, "SWARM_KillEnemy": 0, "SWARM_PickupGold": 0, "SWARM_ReachLevel50": 0, "SWARM_Survive15Min": 0, "SWARM_WinWith5EvolvedWeapons": 0, "abilityUses": 333, "acesBefore15Minutes": 0, "alliedJungleMonsterKills": 60, "baronBuffGoldAdvantageOverThreshold": 1, "baronTakedowns": 1, "blastConeOppositeOpponentCount": 0, "bountyGold": 0, "buffsStolen": 1, "completeSupportQuestInTime": 0, "controlWardTimeCoverageInRiverOrEnemyHalf": 0.1721459301028285, "controlWardsPlaced": 1, "damagePerMinute": 834.5667290618521, "damageTakenOnTeamPercentage": 0.17805327892147935, "dancedWithRiftHerald": 0, "deathsByEnemyChamps": 2, "dodgeSkillShotsSmallWindow": 0, "doubleAces": 0, "dragonTakedowns": 3, "earliestBaron": 1273.266770099, "earliestDragonTakedown": 654.366752218, "earlyLaningPhaseGoldExpAdvantage": 0, "effectiveHealAndShielding": 0, "elderDragonKillsWithOpposingSoul": 0, "elderDragonMultikills": 0, "enemyChampionImmobilizations": 11, "enemyJungleMonsterKills": 12, "epicMonsterKillsNearEnemyJungler": 1, "epicMonsterKillsWithin30SecondsOfSpawn": 1, "epicMonsterSteals": 0, "epicMonsterStolenWithoutSmite": 0, "firstTurretKilled": 0, "fistBumpParticipation": 0, "flawlessAces": 0, "fullTeamTakedown": 0, "gameLength": 1702.403612063, "goldPerMinute": 447.60652953081893, "hadOpenNexus": 0, "immobilizeAndKillWithAlly": 9, "initialBuffCount": 2, "initialCrabCount": 1, "jungleCsBefore10Minutes": 50.000000059604645, "junglerKillsEarlyJungle": 0, "junglerTakedownsNearDamagedEpicMonster": 0, "kTurretsDestroyedBeforePlatesFall": 0, "kda": 11.5, "killAfterHiddenWithAlly": 3, "killParticipation": 0.5476190476190477, "killedChampTookFullTeamDamageSurvived": 0, "killingSprees": 2, "killsNearEnemyTurret": 0, "killsOnLanersEarlyJungleAsJungler": 0, "killsOnRecentlyHealedByAramPack": 0, "killsUnderOwnTurret": 0, "killsWithHelpFromEpicMonster": 1, "knockEnemyIntoTeamAndKill": 0, "landSkillShotsEarlyGame": 0, "laneMinionsFirst10Minutes": 5, "laningPhaseGoldExpAdvantage": 0, "legendaryCount": 0, "legendaryItemUsed": [3115, 3102, 3157], "lostAnInhibitor": 0, "maxCsAdvantageOnLaneOpponent": 14.800000041723251, "maxKillDeficit": 1, "maxLevelLeadLaneOpponent": 2, "mejaisFullStackInTime": 0, "moreEnemyJungleThanOpponent": -57.000000059604645, "multiKillOneSpell": 0, "multiTurretRiftHeraldCount": 0, "multikills": 2, "multikillsAfterAggressiveFlash": 1, "outerTurretExecutesBefore10Minutes": 0, "outnumberedKills": 0, "outnumberedNexusKill": 0, "perfectDrag ...

# %%
meta_df = pd.DataFrame(data['metadata_json'])
meta_df

styles_list = []

for index, row in data.iterrows():

    summoner_id = row['summonerId']
    meta_json = row['metadata_json']

    meta_dict = json.loads(meta_json)

meta_dict
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_7205539746',
#   'participants': ['kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gEZ67q3zZzR6hL-HZAxRGlenitD8zLIVMQ',
#    'XibJt-p-Uw6NnbxmD5kMzgMGdfs-8ntiAC4KxD3Q9zCA_G1voKD9QYzc7s3wibPLZVDcN3uvfac1iw',
#    'AFIw04dvfgj-a86L1pwEB4A-GTcsx9TVTtbnbTDIK2I7N6n2wjKdwhPtAC_bmdFItsqUKcoD6-p5bA',
#    'kLWZTBCQGvl-Ugepl3b2QLwCgnmeZcomVMdK7CfgRghb-X6-uj5Ggal-Tlesm_34eiV7Fg83-Ds8Uw',
#    '5SQs9wyxfJj9rI3-UK7En6NjI7OLsNrgESUEP4NuEcS7vZ5mSNoglDnTclgLN-LFda3y9Lhoh9Mc8w',
#    'Vcd0QPK1Rp6fl-ILXSm2yCjSy6WK_KzVk28kShTvztmllQ_UM-ecmGX6mcNW3ygnyOFbG6kySWGJeg',
#    'Zh9yMv46DZ8YC7Ja5Fj10N86y720B2leMEX8q3Q0yeM0WUjKXpPJyXp9LEJtb7cHjuWjQ8vxvKU5qA',
#    '9wBGblmUbsi-nFRtTliGuPg-6fgJP2r5pGOnh3GK8zVTHyvFwKh4Tb0XOjW0nmeBFHIRP1Ez_k5_3Q',
#    'W8ng0ipntpuf056n9wqQu3XcRb2NcSG1sbLSFgpkIncr1iV1mHE67p8y3Fk2mYgvqfOLnysTxzGw-A',
#    'dJNSncUcpJcvXo-b8oqlyIPMrQi0k6EzFiCVIgeexfb9mUGUOTjAlf3oyi8F2KWzs5vGAElehM1KuQ']},
#  'info': {'endOfGameResult': 'GameComplete',
#   'gameCreation': 1722855505412,
#   'gameDuration': 1720,
#   'gameEndTimestamp': 1722857257849,
#   'gameId': 7205539746,
#   'gameMode': 'CLASSIC',
#   'gameName': 'teambuilder-match-7205539746',
#   'gameStartTimestamp': 1722855537624,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '14.15.604.8769',
#   'mapId': 11,
#   'participants': [{'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 4,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 281,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 3,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 675,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.8690444937815998,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 1235.4252837628471,
#      'damageTakenOnTeamPercentage': 0.2969019512092537,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 6,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 18,
#      'enemyJungleMonsterKills': 1,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1720.506275095,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 473.8325269359949,
#      'hadOpenNexus': 0,
#      'highestChampionDamage': 1,
#      'immobilizeAndKillWithAlly': 1,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.142857142857143,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.6521739130434783,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 2,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 4,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 67,
#      'laningPhaseGoldExpAdvantage': 1,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3116, 4633, 6653, 3075],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 90.75,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 3,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 2,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 6,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 1,
#      'skillshotsDodged': 73,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 8,
#      'stealthWardsPlaced': 8,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 5,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 15,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 7,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.384860130857553,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 1.064833641052246,
#      'visionScorePerMinute': 0.8125332744484867,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 18448,
#     'champLevel': 18,
#     'championId': 82,
#     'championName': 'Mordekaiser',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 1665,
#     'damageDealtToObjectives': 1989,
#     'damageDealtToTurrets': 1665,
#     'damageSelfMitigated': 42831,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 9,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 3,
#     'goldEarned': 13587,
#     'goldSpent': 13725,
#     'holdPings': 0,
#     'individualPosition': 'TOP',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 6653,
#     'item1': 3116,
#     'item2': 3047,
#     'item3': 3075,
#     'item4': 4633,
#     'item5': 1052,
#     'item6': 3340,
#     'itemsPurchased': 19,
#     'killingSprees': 4,
#     'kills': 11,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 381,
#     'magicDamageDealt': 160912,
#     'magicDamageDealtToChampions': 30115,
#     'magicDamageTaken': 17528,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 17,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 3,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 790, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 1759, 'var2': 300, 'var3': 0},
#         {'perk': 9105, 'var1': 12, 'var2': 0, 'var3': 0},
#         {'perk': 8299, 'var1': 1626, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8473, 'var1': 1443, 'var2': 0, 'var3': 0},
#         {'perk': 8453, 'var1': 1286, 'var2': 1967, 'var3': 0}],
#        'style': 8400}]},
#     'physicalDamageDealt': 24801,
#     'physicalDamageDealtToChampions': 5190,
#     'physicalDamageTaken': 17637,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5067,
#     'pushPings': 0,
#     'puuid': 'kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gEZ67q3zZzR6hL-HZAxRGlenitD8zLIVMQ',
#     'quadraKills': 0,
#     'riotIdGameName': '우빈환혁시후민준열연관우단율',
#     'riotIdTagline': '0000',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 133,
#     'spell2Casts': 76,
#     'spell3Casts': 61,
#     'spell4Casts': 11,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 12,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'EqN2ktKYrXn1twsHNu1y71_fQpFx3lcEKzLgIDV3-_XVxjEV',
#     'summonerLevel': 110,
#     'summonerName': '최강이 구른다',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'TOP',
#     'timeCCingOthers': 23,
#     'timePlayed': 1720,
#     'totalAllyJungleMinionsKilled': 12,
#     'totalDamageDealt': 186930,
#     'totalDamageDealtToChampions': 35425,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 36866,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 10603,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 210,
#     'totalTimeCCDealt': 468,
#     'totalTimeSpentDead': 167,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1215,
#     'trueDamageDealtToChampions': 119,
#     'trueDamageTaken': 1700,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 23,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 9,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 1,
#     'assists': 5,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 214,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 67,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.46068922138179036,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 538.2562988865678,
#      'damageTakenOnTeamPercentage': 0.23218000131590302,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 3,
#      'doubleAces': 0,
#      'dragonTakedowns': 1,
#      'earliestDragonTakedown': 1256.5777657200001,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 56,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 1,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 1,
#      'epicMonsterSteals': 1,
#      'epicMonsterStolenWithoutSmite': 1,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1720.506275095,
#      'goldPerMinute': 299.58011785094465,
#      'hadOpenNexus': 0,
#      'highestWardKills': 1,
#      'immobilizeAndKillWithAlly': 2,
#      'initialBuffCount': 2,
#      'initialCrabCount': 1,
#      'jungleCsBefore10Minutes': 64.00000008940697,
#      'junglerKillsEarlyJungle': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.7777777777777778,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.30434782608695654,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnLanersEarlyJungleAsJungler': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 2,
#      'killsWithHelpFromEpicMonster': 1,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 0,
#      'laneMinionsFirst10Minutes': 1,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6698, 6699],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 13.000000029802322,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': -54.50000008940697,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 6,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 3,
#      'skillshotsDodged': 52,
#      'skillshotsHit': 0,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 1,
#      'stealthWardsPlaced': 2,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 7,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.1676777967449725,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.17519426345825195,
#      'visionScorePerMinute': 1.1725191222897282,
#      'voidMonsterKill': 2,
#      'wardTakedowns': 5,
#      'wardTakedownsBefore20M': 3,
#      'wardsGuarded': 1},
#     'champExperience': 10898,
#     'champLevel': 13,
#     'championId': 35,
#     'championName': 'Shaco',
#     'championTransform': 0,
#     'commandPings': 6,
#     'consumablesPurchased': 2,
#     'damageDealtToBuildings': 0,
#     'damageDealtToObjectives': 10513,
#     'damageDealtToTurrets': 0,
#     'damageSelfMitigated': 13811,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 1,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 3,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 3,
#     'goldEarned': 8590,
#     'goldSpent': 7830,
#     'holdPings': 0,
#     'individualPosition': 'JUNGLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 6699,
#     'item1': 6698,
#     'item2': 3009,
#     'item3': 0,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 18,
#     'killingSprees': 0,
#     'kills': 2,
#     'lane': 'JUNGLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 493,
#     'magicDamageDealt': 55193,
#     'magicDamageDealtToChampions': 6541,
#     'magicDamageTaken': 12399,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 2,
#     'neutralMinionsKilled': 116,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 1,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 8,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 9923, 'var1': 40, 'var2': 74, 'var3': 0},
#         {'perk': 8143, 'var1': 1028, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 8, 'var2': 0, 'var3': 0},
#         {'perk': 8105, 'var1': 9, 'var2': 4, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 269, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 13, 'var2': 10, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 75101,
#     'physicalDamageDealtToChampions': 5702,
#     'physicalDamageTaken': 15812,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5901,
#     'pushPings': 0,
#     'puuid': 'XibJt-p-Uw6NnbxmD5kMzgMGdfs-8ntiAC4KxD3Q9zCA_G1voKD9QYzc7s3wibPLZVDcN3uvfac1iw',
#     'quadraKills': 0,
#     'riotIdGameName': 'WWWMWWNW',
#     'riotIdTagline': 'KR1',
#     'role': 'NONE',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 58,
#     'spell2Casts': 71,
#     'spell3Casts': 73,
#     'spell4Casts': 12,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 14,
#     'summoner2Casts': 15,
#     'summoner2Id': 11,
#     'summonerId': '04ELlsipdbVhMUwerIOIzwxaAV7_i3cTFFVNxMf2eAG3WlQ',
#     'summonerLevel': 169,
#     'summonerName': 'WWWMWWNW',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'JUNGLE',
#     'timeCCingOthers': 29,
#     'timePlayed': 1720,
#     'totalAllyJungleMinionsKilled': 91,
#     'totalDamageDealt': 171108,
#     'totalDamageDealtToChampions': 15434,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 28830,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 9654,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 35,
#     'totalTimeCCDealt': 595,
#     'totalTimeSpentDead': 230,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 40814,
#     'trueDamageDealtToChampions': 3190,
#     'trueDamageTaken': 618,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 33,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 5,
#     'wardsPlaced': 4,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 1,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 228,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 6,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 375,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.4864185809655302,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 553.6013347349796,
#      'damageTakenOnTeamPercentage': 0.17849556168996994,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 9,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 1,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1720.506275095,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 299.58761019502185,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.5555555555555556,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.21739130434782608,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 14,
#      'laneMinionsFirst10Minutes': 64,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [6692, 6699],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 15,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 1,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 1,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 2,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 32,
#      'skillshotsHit': 50,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 2,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 5,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 4,
#      'takedownsInAlcove': 1,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.17245808785788064,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 1,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.2241290807723999,
#      'visionScorePerMinute': 0.4083784153309115,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 10795,
#     'champLevel': 13,
#     'championId': 238,
#     'championName': 'Zed',
#     'championTransform': 0,
#     'commandPings': 3,
#     'consumablesPurchased': 3,
#     'damageDealtToBuildings': 1864,
#     'damageDealtToObjectives': 1864,
#     'damageDealtToTurrets': 1864,
#     'damageSelfMitigated': 11070,
#     'dangerPings': 0,
#     'deaths': 9,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 1,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 8590,
#     'goldSpent': 7825,
#     'holdPings': 0,
#     'individualPosition': 'MIDDLE',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 1055,
#     'item1': 2031,
#     'item2': 3158,
#     'item3': 6692,
#     'item4': 6699,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 17,
#     'killingSprees': 1,
#     'kills': 4,
#     'lane': 'MIDDLE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 323,
#     'magicDamageDealt': 4586,
#     'magicDamageDealtToChampions': 501,
#     'magicDamageTaken': 16825,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 4,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 4,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 809, 'var2': 0, 'var3': 0},
#         {'perk': 8143, 'var1': 572, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 6, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 3, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 292, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 383, 'var2': 100, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 74681,
#     'physicalDamageDealtToChampions': 13882,
#     'physicalDamageTaken': 4054,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 3157,
#     'pushPings': 0,
#     'puuid': 'AFIw04dvfgj-a86L1pwEB4A-GTcsx9TVTtbnbTDIK2I7N6n2wjKdwhPtAC_bmdFItsqUKcoD6-p5bA',
#     'quadraKills': 0,
#     'riotIdGameName': '흑인 인권운동가',
#     'riotIdTagline': '5533',
#     'role': 'SOLO',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 80,
#     'spell2Casts': 74,
#     'spell3Casts': 59,
#     'spell4Casts': 15,
#     'subteamPlacement': 0,
#     'summoner1Casts': 4,
#     'summoner1Id': 4,
#     'summoner2Casts': 5,
#     'summoner2Id': 14,
#     'summonerId': 'SVtXl0tTWq4TaeZs9-aURNk011EIhDjgvub7ED7-B9z7hiVCpzkNuO3a-A',
#     'summonerLevel': 142,
#     'summonerName': 'YOURIS',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'MIDDLE',
#     'timeCCingOthers': 8,
#     'timePlayed': 1720,
#     'totalAllyJungleMinionsKilled': 4,
#     'totalDamageDealt': 81396,
#     'totalDamageDealtToChampions': 15874,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 22164,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 1601,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 126,
#     'totalTimeCCDealt': 112,
#     'totalTimeSpentDead': 296,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2128,
#     'trueDamageDealtToChampions': 1490,
#     'trueDamageTaken': 1284,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 11,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 2,
#     'wardsPlaced': 5,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 0,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 697,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 6,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 850,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 657.2481749957938,
#      'damageTakenOnTeamPercentage': 0.2058263455018082,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 8,
#      'dodgeSkillShotsSmallWindow': 18,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1720.506275095,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 463.5229933735436,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.75,
#      'killAfterHiddenWithAlly': 2,
#      'killParticipation': 0.2608695652173913,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 85,
#      'laneMinionsFirst10Minutes': 74,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3087, 3085, 3031],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 40.749999940395355,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 6,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 155,
#      'skillshotsHit': 336,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'soloTurretsLategame': 1,
#      'stealthWardsPlaced': 4,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 6,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 1,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.20474618899197244,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 2,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.04334867000579834,
#      'visionScorePerMinute': 0.6360866424710133,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 1,
#      'wardsGuarded': 0},
#     'champExperience': 12724,
#     'champLevel': 14,
#     'championId': 221,
#     'championName': 'Zeri',
#     'championTransform': 0,
#     'commandPings': 2,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 4617,
#     'damageDealtToObjectives': 4617,
#     'damageDealtToTurrets': 4617,
#     'damageSelfMitigated': 13706,
#     'dangerPings': 0,
#     'deaths': 8,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 4,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 13291,
#     'goldSpent': 12305,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 3031,
#     'item1': 3087,
#     'item2': 3085,
#     'item3': 3035,
#     'item4': 0,
#     'item5': 3006,
#     'item6': 3363,
#     'itemsPurchased': 27,
#     'killingSprees': 2,
#     'kills': 6,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 763,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 454,
#     'magicDamageDealt': 45588,
#     'magicDamageDealtToChampions': 6244,
#     'magicDamageTaken': 10464,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 8,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5011, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8021, 'var1': 1372, 'var2': 1492, 'var3': 0},
#         {'perk': 9101, 'var1': 1711, 'var2': 0, 'var3': 0},
#         {'perk': 9104, 'var1': 23, 'var2': 10, 'var3': 0},
#         {'perk': 8017, 'var1': 1010, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8313, 'var1': 3, 'var2': 0, 'var3': 0},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 126126,
#     'physicalDamageDealtToChampions': 12425,
#     'physicalDamageTaken': 14090,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5980,
#     'pushPings': 0,
#     'puuid': 'kLWZTBCQGvl-Ugepl3b2QLwCgnmeZcomVMdK7CfgRghb-X6-uj5Ggal-Tlesm_34eiV7Fg83-Ds8Uw',
#     'quadraKills': 0,
#     'riotIdGameName': '호스림',
#     'riotIdTagline': '3478',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 601,
#     'spell2Casts': 42,
#     'spell3Casts': 43,
#     'spell4Casts': 11,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 21,
#     'summoner2Casts': 5,
#     'summoner2Id': 4,
#     'summonerId': 'nU-bB8KwNgl0sAxjfO0pT4nA6ImTmxRZOC4DBKn9QZ9bZRzC4g2JwVablg',
#     'summonerLevel': 210,
#     'summonerName': '호스림',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 5,
#     'timePlayed': 1720,
#     'totalAllyJungleMinionsKilled': 8,
#     'totalDamageDealt': 189635,
#     'totalDamageDealtToChampions': 18846,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25557,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 3747,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 244,
#     'totalTimeCCDealt': 89,
#     'totalTimeSpentDead': 171,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 17918,
#     'trueDamageDealtToChampions': 177,
#     'trueDamageTaken': 1002,
#     'turretKills': 2,
#     'turretTakedowns': 2,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 18,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 7,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 2,
#     'assists': 9,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 268,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronTakedowns': 0,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 1,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5825244294971608,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 225.53195314767126,
#      'damageTakenOnTeamPercentage': 0.08659614028306512,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 4,
#      'dodgeSkillShotsSmallWindow': 1,
#      'doubleAces': 0,
#      'dragonTakedowns': 2,
#      'earliestDragonTakedown': 1256.5777657200001,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 8746.95703125,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 0,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'fasterSupportQuestCompletion': 1,
#      'firstTurretKilled': 0,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 0,
#      'gameLength': 1720.506275095,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 234.15604985384613,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 0,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 2.25,
#      'killAfterHiddenWithAlly': 3,
#      'killParticipation': 0.391304347826087,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 10,
#      'laneMinionsFirst10Minutes': 11,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3870, 3222, 6617],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 2,
#      'maxKillDeficit': 0,
#      'maxLevelLeadLaneOpponent': 2,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 9,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 14,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 34,
#      'skillshotsHit': 79,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 30,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 0,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 9,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 3,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 0,
#      'teamDamagePercentage': 0.0702577955476214,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 0,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.1494470238685608,
#      'visionScorePerMinute': 2.103404161664146,
#      'voidMonsterKill': 0,
#      'wardTakedowns': 2,
#      'wardTakedownsBefore20M': 2,
#      'wardsGuarded': 0},
#     'champExperience': 11514,
#     'champLevel': 14,
#     'championId': 350,
#     'championName': 'Yuumi',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 67,
#     'damageDealtToObjectives': 261,
#     'damageDealtToTurrets': 67,
#     'damageSelfMitigated': 4051,
#     'dangerPings': 0,
#     'deaths': 4,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 6714,
#     'goldSpent': 6550,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 2,
#     'item0': 3870,
#     'item1': 3222,
#     'item2': 6617,
#     'item3': 3158,
#     'item4': 1052,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 21,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 24,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 689,
#     'magicDamageDealt': 8737,
#     'magicDamageDealtToChampions': 5239,
#     'magicDamageTaken': 6585,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 1,
#     'onMyWayPings': 1,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8229, 'var1': 1597, 'var2': 0, 'var3': 0},
#         {'perk': 8226, 'var1': 250, 'var2': 174, 'var3': 0},
#         {'perk': 8210, 'var1': 2, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 654, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8017, 'var1': 350, 'var2': 0, 'var3': 0},
#         {'perk': 8009, 'var1': 1883, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 2674,
#     'physicalDamageDealtToChampions': 498,
#     'physicalDamageTaken': 4014,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6502,
#     'pushPings': 0,
#     'puuid': '5SQs9wyxfJj9rI3-UK7En6NjI7OLsNrgESUEP4NuEcS7vZ5mSNoglDnTclgLN-LFda3y9Lhoh9Mc8w',
#     'quadraKills': 0,
#     'riotIdGameName': '유순덕',
#     'riotIdTagline': 'KR1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 75,
#     'spell2Casts': 125,
#     'spell3Casts': 59,
#     'spell4Casts': 9,
#     'subteamPlacement': 0,
#     'summoner1Casts': 6,
#     'summoner1Id': 3,
#     'summoner2Casts': 6,
#     'summoner2Id': 14,
#     'summonerId': 'NLZ-1HhnzgXaiEKCorCWvbWogju-_OF8h9g_67TiMjLB80kCjhwXJEZp3g',
#     'summonerLevel': 120,
#     'summonerName': '유순덕',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 19,
#     'timePlayed': 1720,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 14240,
#     'totalDamageDealtToChampions': 6467,
#     'totalDamageShieldedOnTeammates': 3881,
#     'totalDamageTaken': 10752,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 6459,
#     'totalHealsOnTeammates': 4865,
#     'totalMinionsKilled': 17,
#     'totalTimeCCDealt': 213,
#     'totalTimeSpentDead': 63,
#     'totalUnitsHealed': 5,
#     'tripleKills': 0,
#     'trueDamageDealt': 2828,
#     'trueDamageDealtToChampions': 730,
#     'trueDamageTaken': 152,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 10,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 60,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 2,
#     'wardsPlaced': 32,
#     'win': False},
#    {'allInPings': 0,
#     'assistMePings': 0,
#     'assists': 1,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 0,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 150,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.5801317606242892,
#      'controlWardsPlaced': 1,
#      'damagePerMinute': 403.46923327432813,
#      'damageTakenOnTeamPercentage': 0.21324569736363647,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 7,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1303.8809347400002,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 0,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 19,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 837.831738315,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 1720.506275095,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 322.8185765774566,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 1,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 0.5714285714285714,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.10810810810810811,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 1,
#      'killsNearEnemyTurret': 1,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 2,
#      'landSkillShotsEarlyGame': 28,
#      'laneMinionsFirst10Minutes': 45,
#      'laningPhaseGoldExpAdvantage': 0,
# ...
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 3,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 7,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 0,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 154,
#      'skillshotsHit': 55,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 6,
#      'stealthWardsPlaced': 6,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 15,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 6,
#      'takedownsInAlcove': 2,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.2404296981982544,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 1,
#      'turretTakedowns': 2,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': -0.04154759645462036,
#      'visionScorePerMinute': 0.6096587689649552,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 1,
#      'wardTakedownsBefore20M': 0,
#      'wardsGuarded': 0},
#     'champExperience': 15073,
#     'champLevel': 16,
#     'championId': 22,
#     'championName': 'Ashe',
#     'championTransform': 0,
#     'commandPings': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 4408,
#     'damageDealtToObjectives': 6803,
#     'damageDealtToTurrets': 4408,
#     'damageSelfMitigated': 15065,
#     'dangerPings': 0,
#     'deaths': 7,
#     'detectorWardsPlaced': 1,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 0,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 12455,
#     'goldSpent': 12350,
#     'holdPings': 0,
#     'individualPosition': 'BOTTOM',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 3087,
#     'item1': 6672,
#     'item2': 3153,
#     'item3': 3009,
#     'item4': 1037,
#     'item5': 1018,
#     'item6': 3340,
#     'itemsPurchased': 29,
#     'killingSprees': 3,
#     'kills': 7,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 213,
#     'largestKillingSpree': 2,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 614,
#     'magicDamageDealt': 23207,
#     'magicDamageDealtToChampions': 1968,
#     'magicDamageTaken': 8507,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 22,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 10,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 1706, 'var2': 1706, 'var3': 0},
#         {'perk': 9111, 'var1': 986, 'var2': 300, 'var3': 0},
#         {'perk': 9104, 'var1': 15, 'var2': 30, 'var3': 0},
#         {'perk': 8014, 'var1': 514, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8126, 'var1': 1049, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 149917,
#     'physicalDamageDealtToChampions': 21723,
#     'physicalDamageTaken': 15289,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 5244,
#     'pushPings': 0,
#     'puuid': 'W8ng0ipntpuf056n9wqQu3XcRb2NcSG1sbLSFgpkIncr1iV1mHE67p8y3Fk2mYgvqfOLnysTxzGw-A',
#     'quadraKills': 0,
#     'riotIdGameName': 'ss88088',
#     'riotIdTagline': 'KR12',
#     'role': 'CARRY',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 28,
#     'spell2Casts': 74,
#     'spell3Casts': 10,
#     'spell4Casts': 10,
#     'subteamPlacement': 0,
#     'summoner1Casts': 5,
#     'summoner1Id': 21,
#     'summoner2Casts': 4,
#     'summoner2Id': 4,
#     'summonerId': 'yLYMQK09E4q4k28NY1wvH0dZ0iy0FrqP5OPkjAlg4DmGtgtL',
#     'summonerLevel': 268,
#     'summonerName': '윤자바라기렉자',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'BOTTOM',
#     'timeCCingOthers': 44,
#     'timePlayed': 1720,
#     'totalAllyJungleMinionsKilled': 14,
#     'totalDamageDealt': 185965,
#     'totalDamageDealtToChampions': 24941,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 24475,
#     'totalEnemyJungleMinionsKilled': 6,
#     'totalHeal': 5944,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 187,
#     'totalTimeCCDealt': 777,
#     'totalTimeSpentDead': 181,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 12841,
#     'trueDamageDealtToChampions': 1248,
#     'trueDamageTaken': 677,
#     'turretKills': 0,
#     'turretTakedowns': 2,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 17,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 7,
#     'win': True},
#    {'allInPings': 1,
#     'assistMePings': 0,
#     'assists': 13,
#     'baronKills': 0,
#     'basicPings': 0,
#     'bountyLevel': 0,
#     'challenges': {'12AssistStreakCount': 1,
#      'InfernalScalePickup': 0,
#      'SWARM_DefeatAatrox': 0,
#      'SWARM_DefeatBriar': 0,
#      'SWARM_DefeatMiniBosses': 0,
#      'SWARM_EvolveWeapon': 0,
#      'SWARM_Have3Passives': 0,
#      'SWARM_KillEnemy': 0,
#      'SWARM_PickupGold': 0,
#      'SWARM_ReachLevel50': 0,
#      'SWARM_Survive15Min': 0,
#      'SWARM_WinWith5EvolvedWeapons': 0,
#      'abilityUses': 270,
#      'acesBefore15Minutes': 0,
#      'alliedJungleMonsterKills': 0,
#      'baronBuffGoldAdvantageOverThreshold': 1,
#      'baronTakedowns': 1,
#      'blastConeOppositeOpponentCount': 0,
#      'bountyGold': 0,
#      'buffsStolen': 0,
#      'completeSupportQuestInTime': 0,
#      'controlWardTimeCoverageInRiverOrEnemyHalf': 0.8351861959658691,
#      'controlWardsPlaced': 2,
#      'damagePerMinute': 234.293278946842,
#      'damageTakenOnTeamPercentage': 0.08859918421207628,
#      'dancedWithRiftHerald': 0,
#      'deathsByEnemyChamps': 0,
#      'dodgeSkillShotsSmallWindow': 0,
#      'doubleAces': 0,
#      'dragonTakedowns': 0,
#      'earliestBaron': 1303.8809347400002,
#      'earlyLaningPhaseGoldExpAdvantage': 0,
#      'effectiveHealAndShielding': 5607.51025390625,
#      'elderDragonKillsWithOpposingSoul': 0,
#      'elderDragonMultikills': 0,
#      'enemyChampionImmobilizations': 14,
#      'enemyJungleMonsterKills': 0,
#      'epicMonsterKillsNearEnemyJungler': 0,
#      'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#      'epicMonsterSteals': 0,
#      'epicMonsterStolenWithoutSmite': 0,
#      'firstTurretKilled': 1,
#      'firstTurretKilledTime': 837.831738315,
#      'fistBumpParticipation': 0,
#      'flawlessAces': 0,
#      'fullTeamTakedown': 1,
#      'gameLength': 1720.506275095,
#      'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#      'goldPerMinute': 278.3383688210075,
#      'hadOpenNexus': 0,
#      'immobilizeAndKillWithAlly': 1,
#      'initialBuffCount': 0,
#      'initialCrabCount': 0,
#      'jungleCsBefore10Minutes': 0,
#      'junglerTakedownsNearDamagedEpicMonster': 0,
#      'kTurretsDestroyedBeforePlatesFall': 0,
#      'kda': 13,
#      'killAfterHiddenWithAlly': 1,
#      'killParticipation': 0.35135135135135137,
#      'killedChampTookFullTeamDamageSurvived': 0,
#      'killingSprees': 0,
#      'killsNearEnemyTurret': 0,
#      'killsOnOtherLanesEarlyJungleAsLaner': 0,
#      'killsOnRecentlyHealedByAramPack': 0,
#      'killsUnderOwnTurret': 0,
#      'killsWithHelpFromEpicMonster': 0,
#      'knockEnemyIntoTeamAndKill': 0,
#      'landSkillShotsEarlyGame': 13,
#      'laneMinionsFirst10Minutes': 9,
#      'laningPhaseGoldExpAdvantage': 0,
#      'legendaryCount': 0,
#      'legendaryItemUsed': [3869, 3003, 3040, 3026],
#      'lostAnInhibitor': 0,
#      'maxCsAdvantageOnLaneOpponent': 21,
#      'maxKillDeficit': 2,
#      'maxLevelLeadLaneOpponent': 1,
#      'mejaisFullStackInTime': 0,
#      'moreEnemyJungleThanOpponent': 0,
#      'multiKillOneSpell': 0,
#      'multiTurretRiftHeraldCount': 0,
#      'multikills': 0,
#      'multikillsAfterAggressiveFlash': 0,
#      'outerTurretExecutesBefore10Minutes': 0,
#      'outnumberedKills': 0,
#      'outnumberedNexusKill': 0,
#      'perfectDragonSoulsTaken': 0,
#      'perfectGame': 0,
#      'pickKillWithAlly': 11,
#      'playedChampSelectPosition': 1,
#      'poroExplosions': 0,
#      'quickCleanse': 0,
#      'quickFirstTurret': 0,
#      'quickSoloKills': 0,
#      'riftHeraldTakedowns': 0,
#      'saveAllyFromDeath': 3,
#      'scuttleCrabKills': 0,
#      'skillshotsDodged': 18,
#      'skillshotsHit': 65,
#      'snowballsHit': 0,
#      'soloBaronKills': 0,
#      'soloKills': 0,
#      'stealthWardsPlaced': 24,
#      'survivedSingleDigitHpCount': 0,
#      'survivedThreeImmobilizesInFight': 2,
#      'takedownOnFirstTurret': 0,
#      'takedowns': 13,
#      'takedownsAfterGainingLevelAdvantage': 0,
#      'takedownsBeforeJungleMinionSpawn': 0,
#      'takedownsFirstXMinutes': 2,
#      'takedownsInAlcove': 0,
#      'takedownsInEnemyFountain': 0,
#      'teamBaronKills': 1,
#      'teamDamagePercentage': 0.06476444395500278,
#      'teamElderDragonKills': 0,
#      'teamRiftHeraldKills': 0,
#      'tookLargeDamageSurvived': 0,
#      'turretPlatesTaken': 0,
#      'turretTakedowns': 6,
#      'turretsTakenWithRiftHerald': 0,
#      'twentyMinionsIn3SecondsCount': 0,
#      'twoWardsOneSweeperCount': 0,
#      'unseenRecalls': 0,
#      'visionScoreAdvantageLaneOpponent': 0.17570579051971436,
#      'visionScorePerMinute': 2.472984387118882,
#      'voidMonsterKill': 1,
#      'wardTakedowns': 4,
#      'wardTakedownsBefore20M': 4,
#      'wardsGuarded': 0},
#     'champExperience': 11190,
#     'champLevel': 13,
#     'championId': 26,
#     'championName': 'Zilean',
#     'championTransform': 0,
#     'commandPings': 4,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 1144,
#     'damageDealtToObjectives': 2341,
#     'damageDealtToTurrets': 1144,
#     'damageSelfMitigated': 4816,
#     'dangerPings': 0,
#     'deaths': 0,
#     'detectorWardsPlaced': 2,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'eligibleForProgression': True,
#     'enemyMissingPings': 2,
#     'enemyVisionPings': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'getBackPings': 0,
#     'goldEarned': 7981,
#     'goldSpent': 7600,
#     'holdPings': 0,
#     'individualPosition': 'UTILITY',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 1,
#     'inhibitorsLost': 0,
#     'item0': 3869,
#     'item1': 3026,
#     'item2': 3040,
#     'item3': 3009,
#     'item4': 0,
#     'item5': 0,
#     'item6': 3364,
#     'itemsPurchased': 22,
#     'killingSprees': 0,
#     'kills': 0,
#     'lane': 'BOTTOM',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 0,
#     'longestTimeSpentLiving': 0,
#     'magicDamageDealt': 33610,
#     'magicDamageDealtToChampions': 6001,
#     'magicDamageTaken': 5058,
#     'missions': {'playerScore0': 0,
#      'playerScore1': 0,
#      'playerScore2': 0,
#      'playerScore3': 0,
#      'playerScore4': 0,
#      'playerScore5': 0,
#      'playerScore6': 0,
#      'playerScore7': 0,
#      'playerScore8': 0,
#      'playerScore9': 0,
#      'playerScore10': 0,
#      'playerScore11': 0},
#     'needVisionPings': 0,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'onMyWayPings': 3,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5007},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 798, 'var2': 912, 'var3': 0},
#         {'perk': 8224, 'var1': 128, 'var2': 0, 'var3': 0},
#         {'perk': 8210, 'var1': 1, 'var2': 0, 'var3': 0},
#         {'perk': 8232, 'var1': 3, 'var2': 10, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8304, 'var1': 11, 'var2': 1, 'var3': 5},
#         {'perk': 8347, 'var1': 0, 'var2': 0, 'var3': 0}],
#        'style': 8300}]},
#     'physicalDamageDealt': 2625,
#     'physicalDamageDealtToChampions': 716,
#     'physicalDamageTaken': 5489,
#     'placement': 0,
#     'playerAugment1': 0,
#     'playerAugment2': 0,
#     'playerAugment3': 0,
#     'playerAugment4': 0,
#     'playerAugment5': 0,
#     'playerAugment6': 0,
#     'playerSubteamId': 0,
#     'profileIcon': 6500,
#     'pushPings': 0,
#     'puuid': 'dJNSncUcpJcvXo-b8oqlyIPMrQi0k6EzFiCVIgeexfb9mUGUOTjAlf3oyi8F2KWzs5vGAElehM1KuQ',
#     'quadraKills': 0,
#     'riotIdGameName': 'tanvboi 2',
#     'riotIdTagline': 'KR1',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 96,
#     'spell2Casts': 66,
#     'spell3Casts': 100,
#     'spell4Casts': 8,
#     'subteamPlacement': 0,
#     'summoner1Casts': 2,
#     'summoner1Id': 7,
#     'summoner2Casts': 1,
#     'summoner2Id': 4,
#     'summonerId': 'NQTw-vx32Arpw_XfCENTzdCWigDhpWXfZ7wHTxilD5jSa0hh',
#     'summonerLevel': 101,
#     'summonerName': 'tanvboi 2',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': 'UTILITY',
#     'timeCCingOthers': 15,
#     'timePlayed': 1720,
#     'totalAllyJungleMinionsKilled': 0,
#     'totalDamageDealt': 37875,
#     'totalDamageDealtToChampions': 6718,
#     'totalDamageShieldedOnTeammates': 912,
#     'totalDamageTaken': 11080,
#     'totalEnemyJungleMinionsKilled': 0,
#     'totalHeal': 8524,
#     'totalHealsOnTeammates': 4695,
#     'totalMinionsKilled': 38,
#     'totalTimeCCDealt': 75,
#     'totalTimeSpentDead': 0,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 1638,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 532,
#     'turretKills': 1,
#     'turretTakedowns': 6,
#     'turretsLost': 3,
#     'unrealKills': 0,
#     'visionClearedPings': 0,
#     'visionScore': 70,
#     'visionWardsBoughtInGame': 2,
#     'wardsKilled': 4,
#     'wardsPlaced': 27,
#     'win': True}],
#   'platformId': 'KR',
#   'queueId': 420,
#   'teams': [{'bans': [{'championId': 64, 'pickTurn': 1},
#      {'championId': 89, 'pickTurn': 2},
#      {'championId': 7, 'pickTurn': 3},
#      {'championId': 101, 'pickTurn': 4},
#      {'championId': 420, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 23},
#      'dragon': {'first': False, 'kills': 1},
#      'horde': {'first': True, 'kills': 2},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 3}},
#     'teamId': 100,
#     'win': False},
#    {'bans': [{'championId': 893, 'pickTurn': 6},
#      {'championId': -1, 'pickTurn': 7},
#      {'championId': 102, 'pickTurn': 8},
#      {'championId': -1, 'pickTurn': 9},
#      {'championId': 122, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': False, 'kills': 37},
#      'dragon': {'first': True, 'kills': 2},
#      'horde': {'first': False, 'kills': 4},
#      'inhibitor': {'first': True, 'kills': 2},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 10}},
#     'teamId': 200,
#     'win': True}],
#   'tournamentCode': ''}}

# %%
row['summonerId']
# Out:
# 'EqN2ktKYrXn1twsHNu1y71_fQpFx3lcEKzLgIDV3-_XVxjEV'

# %%
row['metadata_json']
# Out:
# '{"metadata": {"dataVersion": "2", "matchId": "KR_7205539746", "participants": ["kKd5dAMiZlnKf5EZEvqKFHKk6WM9q5wgjKOmjJxbKA86gEZ67q3zZzR6hL-HZAxRGlenitD8zLIVMQ", "XibJt-p-Uw6NnbxmD5kMzgMGdfs-8ntiAC4KxD3Q9zCA_G1voKD9QYzc7s3wibPLZVDcN3uvfac1iw", "AFIw04dvfgj-a86L1pwEB4A-GTcsx9TVTtbnbTDIK2I7N6n2wjKdwhPtAC_bmdFItsqUKcoD6-p5bA", "kLWZTBCQGvl-Ugepl3b2QLwCgnmeZcomVMdK7CfgRghb-X6-uj5Ggal-Tlesm_34eiV7Fg83-Ds8Uw", "5SQs9wyxfJj9rI3-UK7En6NjI7OLsNrgESUEP4NuEcS7vZ5mSNoglDnTclgLN-LFda3y9Lhoh9Mc8w", "Vcd0QPK1Rp6fl-ILXSm2yCjSy6WK_KzVk28kShTvztmllQ_UM-ecmGX6mcNW3ygnyOFbG6kySWGJeg", "Zh9yMv46DZ8YC7Ja5Fj10N86y720B2leMEX8q3Q0yeM0WUjKXpPJyXp9LEJtb7cHjuWjQ8vxvKU5qA", "9wBGblmUbsi-nFRtTliGuPg-6fgJP2r5pGOnh3GK8zVTHyvFwKh4Tb0XOjW0nmeBFHIRP1Ez_k5_3Q", "W8ng0ipntpuf056n9wqQu3XcRb2NcSG1sbLSFgpkIncr1iV1mHE67p8y3Fk2mYgvqfOLnysTxzGw-A", "dJNSncUcpJcvXo-b8oqlyIPMrQi0k6EzFiCVIgeexfb9mUGUOTjAlf3oyi8F2KWzs5vGAElehM1KuQ"]}, "info": {"endOfGameResult": "GameComplete", "gameCreation": 1722855505412, "gameDuration": 1720, "gameEndTimestamp": 1722857257849, "gameId": 7205539746, "gameMode": "CLASSIC", "gameName": "teambuilder-match-7205539746", "gameStartTimestamp": 1722855537624, "gameType": "MATCHED_GAME", "gameVersion": "14.15.604.8769", "mapId": 11, "participants": [{"allInPings": 0, "assistMePings": 0, "assists": 4, "baronKills": 0, "basicPings": 0, "bountyLevel": 0, "challenges": {"12AssistStreakCount": 0, "InfernalScalePickup": 0, "SWARM_DefeatAatrox": 0, "SWARM_DefeatBriar": 0, "SWARM_DefeatMiniBosses": 0, "SWARM_EvolveWeapon": 0, "SWARM_Have3Passives": 0, "SWARM_KillEnemy": 0, "SWARM_PickupGold": 0, "SWARM_ReachLevel50": 0, "SWARM_Survive15Min": 0, "SWARM_WinWith5EvolvedWeapons": 0, "abilityUses": 281, "acesBefore15Minutes": 0, "alliedJungleMonsterKills": 3, "baronTakedowns": 0, "blastConeOppositeOpponentCount": 0, "bountyGold": 675, "buffsStolen": 0, "completeSupportQuestInTime": 0, "controlWardTimeCoverageInRiverOrEnemyHalf": 0.8690444937815998, "controlWardsPlaced": 1, "damagePerMinute": 1235.4252837628471, "damageTakenOnTeamPercentage": 0.2969019512092537, "dancedWithRiftHerald": 0, "deathsByEnemyChamps": 7, "dodgeSkillShotsSmallWindow": 6, "doubleAces": 0, "dragonTakedowns": 0, "earlyLaningPhaseGoldExpAdvantage": 0, "effectiveHealAndShielding": 0, "elderDragonKillsWithOpposingSoul": 0, "elderDragonMultikills": 0, "enemyChampionImmobilizations": 18, "enemyJungleMonsterKills": 1, "epicMonsterKillsNearEnemyJungler": 0, "epicMonsterKillsWithin30SecondsOfSpawn": 0, "epicMonsterSteals": 0, "epicMonsterStolenWithoutSmite": 0, "firstTurretKilled": 0, "fistBumpParticipation": 0, "flawlessAces": 0, "fullTeamTakedown": 0, "gameLength": 1720.506275095, "getTakedownsInAllLanesEarlyJungleAsLaner": 0, "goldPerMinute": 473.8325269359949, "hadOpenNexus": 0, "highestChampionDamage": 1, "immobilizeAndKillWithAlly": 1, "initialBuffCount": 0, "initialCrabCount": 0, "jungleCsBefore10Minutes": 0, "junglerTakedownsNearDamagedEpicMonster": 0, "kTurretsDestroyedBeforePlatesFall": 0, "kda": 2.142857142857143, "killAfterHiddenWithAlly": 1, "killParticipation": 0.6521739130434783, "killedChampTookFullTeamDamageSurvived": 0, "killingSprees": 2, "killsNearEnemyTurret": 0, "killsOnOtherLanesEarlyJungleAsLaner": 0, "killsOnRecentlyHealedByAramPack": 0, "killsUnderOwnTurret": 0, "killsWithHelpFromEpicMonster": 0, "knockEnemyIntoTeamAndKill": 4, "landSkillShotsEarlyGame": 0, "laneMinionsFirst10Minutes": 67, "laningPhaseGoldExpAdvantage": 1, "legendaryCount": 0, "legendaryItemUsed": [3116, 4633, 6653, 3075], "lostAnInhibitor": 0, "maxCsAdvantageOnLaneOpponent": 90.75, "maxKillDeficit": 0, "maxLevelLeadLaneOpponent": 3, "mejaisFullStackInTime": 0, "moreEnemyJungleThanOpponent": 0, "multiKillOneSpell": 0, "multiTurretRiftHeraldCount": 0, "multikills": 0, "multikillsAfterAggressiveFlash": 0, "outerTurretExecutesBefore10Minutes": 0, "outnumberedKills": 2, "outnumberedNexusKill": 0, "perfectDragonSoulsTaken": 0, "perfectGame": 0, "pickKillWithAlly": 6, "playedChampSelectPosition": 1, "poroExp ...

# %%
data['summonerId'][0]
# Out:
# 'P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3'

# %%
a = json.loads(row['metadata_json'])
# a['info']['participants'][0]['challenges']

a['info']['participants'][['summonerId'] == 'P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3']['challenges']
# Out:
# {'12AssistStreakCount': 0,
#  'InfernalScalePickup': 0,
#  'SWARM_DefeatAatrox': 0,
#  'SWARM_DefeatBriar': 0,
#  'SWARM_DefeatMiniBosses': 0,
#  'SWARM_EvolveWeapon': 0,
#  'SWARM_Have3Passives': 0,
#  'SWARM_KillEnemy': 0,
#  'SWARM_PickupGold': 0,
#  'SWARM_ReachLevel50': 0,
#  'SWARM_Survive15Min': 0,
#  'SWARM_WinWith5EvolvedWeapons': 0,
#  'abilityUses': 281,
#  'acesBefore15Minutes': 0,
#  'alliedJungleMonsterKills': 3,
#  'baronTakedowns': 0,
#  'blastConeOppositeOpponentCount': 0,
#  'bountyGold': 675,
#  'buffsStolen': 0,
#  'completeSupportQuestInTime': 0,
#  'controlWardTimeCoverageInRiverOrEnemyHalf': 0.8690444937815998,
#  'controlWardsPlaced': 1,
#  'damagePerMinute': 1235.4252837628471,
#  'damageTakenOnTeamPercentage': 0.2969019512092537,
#  'dancedWithRiftHerald': 0,
#  'deathsByEnemyChamps': 7,
#  'dodgeSkillShotsSmallWindow': 6,
#  'doubleAces': 0,
#  'dragonTakedowns': 0,
#  'earlyLaningPhaseGoldExpAdvantage': 0,
#  'effectiveHealAndShielding': 0,
#  'elderDragonKillsWithOpposingSoul': 0,
#  'elderDragonMultikills': 0,
#  'enemyChampionImmobilizations': 18,
#  'enemyJungleMonsterKills': 1,
#  'epicMonsterKillsNearEnemyJungler': 0,
#  'epicMonsterKillsWithin30SecondsOfSpawn': 0,
#  'epicMonsterSteals': 0,
#  'epicMonsterStolenWithoutSmite': 0,
#  'firstTurretKilled': 0,
#  'fistBumpParticipation': 0,
#  'flawlessAces': 0,
#  'fullTeamTakedown': 0,
#  'gameLength': 1720.506275095,
#  'getTakedownsInAllLanesEarlyJungleAsLaner': 0,
#  'goldPerMinute': 473.8325269359949,
#  'hadOpenNexus': 0,
#  'highestChampionDamage': 1,
#  'immobilizeAndKillWithAlly': 1,
#  'initialBuffCount': 0,
#  'initialCrabCount': 0,
#  'jungleCsBefore10Minutes': 0,
#  'junglerTakedownsNearDamagedEpicMonster': 0,
#  'kTurretsDestroyedBeforePlatesFall': 0,
#  'kda': 2.142857142857143,
#  'killAfterHiddenWithAlly': 1,
#  'killParticipation': 0.6521739130434783,
#  'killedChampTookFullTeamDamageSurvived': 0,
#  'killingSprees': 2,
#  'killsNearEnemyTurret': 0,
#  'killsOnOtherLanesEarlyJungleAsLaner': 0,
#  'killsOnRecentlyHealedByAramPack': 0,
#  'killsUnderOwnTurret': 0,
#  'killsWithHelpFromEpicMonster': 0,
#  'knockEnemyIntoTeamAndKill': 4,
#  'landSkillShotsEarlyGame': 0,
#  'laneMinionsFirst10Minutes': 67,
#  'laningPhaseGoldExpAdvantage': 1,
#  'legendaryCount': 0,
#  'legendaryItemUsed': [3116, 4633, 6653, 3075],
#  'lostAnInhibitor': 0,
#  'maxCsAdvantageOnLaneOpponent': 90.75,
#  'maxKillDeficit': 0,
#  'maxLevelLeadLaneOpponent': 3,
#  'mejaisFullStackInTime': 0,
#  'moreEnemyJungleThanOpponent': 0,
#  'multiKillOneSpell': 0,
#  'multiTurretRiftHeraldCount': 0,
#  'multikills': 0,
#  'multikillsAfterAggressiveFlash': 0,
#  'outerTurretExecutesBefore10Minutes': 0,
#  'outnumberedKills': 2,
#  'outnumberedNexusKill': 0,
#  'perfectDragonSoulsTaken': 0,
#  'perfectGame': 0,
#  'pickKillWithAlly': 6,
#  'playedChampSelectPosition': 1,
#  'poroExplosions': 0,
#  'quickCleanse': 0,
#  'quickFirstTurret': 0,
#  'quickSoloKills': 0,
#  'riftHeraldTakedowns': 0,
#  'saveAllyFromDeath': 0,
#  'scuttleCrabKills': 1,
#  'skillshotsDodged': 73,
#  'skillshotsHit': 0,
#  'snowballsHit': 0,
#  'soloBaronKills': 0,
#  'soloKills': 8,
#  'stealthWardsPlaced': 8,
#  'survivedSingleDigitHpCount': 0,
#  'survivedThreeImmobilizesInFight': 5,
#  'takedownOnFirstTurret': 0,
#  'takedowns': 15,
#  'takedownsAfterGainingLevelAdvantage': 0,
#  'takedownsBeforeJungleMinionSpawn': 0,
#  'takedownsFirstXMinutes': 7,
#  'takedownsInAlcove': 0,
#  'takedownsInEnemyFountain': 0,
#  'teamBaronKills': 0,
#  'teamDamagePercentage': 0.384860130857553,
#  'teamElderDragonKills': 0,
#  'teamRiftHeraldKills': 0,
#  'tookLargeDamageSurvived': 0,
#  'turretPlatesTaken': 2,
#  'turretTakedowns': 1,
#  'turretsTakenWithRiftHerald': 0,
#  'twentyMinionsIn3SecondsCount': 0,
#  'twoWardsOneSweeperCount': 0,
#  'unseenRecalls': 0,
#  'visionScoreAdvantageLaneOpponent': 1.064833641052246,
#  'visionScorePerMinute': 0.8125332744484867,
#  'voidMonsterKill': 1,
#  'wardTakedowns': 1,
#  'wardTakedownsBefore20M': 1,
#  'wardsGuarded': 0}

# %%
meta_df = pd.DataFrame(data['metadata_json'], columns=['metadata_json'])
meta_df

# 데이터를 수집할 시 활용한 서머너id에 부합하는 데이터를 추출 함수


def extract_participant_data(row, summoner_id):
    try:
        # JSON 파싱
        metadata = json.loads(row['metadata_json'])
        participants = metadata['info']['participants']

        # data의 summonerId가 participant['summonerId']와 동일한 조건을 만족하는
        for participant in participants:
            if participant['summonerId'] == summoner_id:
                # participant 딕셔너리 하 115개, participant['challenges'] 하 125개 = 240개
                return {
                    'champExperience': participant.get('champExperience'),
                    'champLevel': participant.get('champLevel'),
                    'championId': participant.get('championId'),
                    'championName': participant.get('championName'),
                    'championTransform': participant.get('championTransform'),
                    'commandPings': participant.get('commandPings'),
                    'consumablesPurchased': participant.get('consumablesPurchased'),
                    'damageDealtToBuildings': participant.get('damageDealtToBuildings'),
                    'damageDealtToObjectives': participant.get('damageDealtToObjectives'),
                    'damageDealtToTurrets': participant.get('damageDealtToTurrets'),
                    'damageSelfMitigated': participant.get('damageSelfMitigated'),
                    'dangerPings': participant.get('dangerPings'),
                    'deaths': participant.get('deaths'),
                    'detectorWardsPlaced': participant.get('detectorWardsPlaced'),
                    'doubleKills': participant.get('doubleKills'),
                    'dragonKills': participant.get('dragonKills'),
                    'eligibleForProgression': participant.get('eligibleForProgression'),
                    'enemyMissingPings': participant.get('enemyMissingPings'),
                    'enemyVisionPings': participant.get('enemyVisionPings'),
                    'firstBloodAssist': participant.get('firstBloodAssist'),
                    'firstBloodKill': participant.get('firstBloodKill'),
                    'firstTowerAssist': participant.get('firstTowerAssist'),
                    'firstTowerKill': participant.get('firstTowerKill'),
                    'gameEndedInEarlySurrender': participant.get('gameEndedInEarlySurrender'),
                    'gameEndedInSurrender': participant.get('gameEndedInSurrender'),
                    'getBackPings': participant.get('getBackPings'),
                    'goldEarned': participant.get('goldEarned'),
                    'goldSpent': participant.get('goldSpent'),
                    'holdPings': participant.get('holdPings'),
                    'individualPosition': participant.get('individualPosition'),
                    'inhibitorKills': participant.get('inhibitorKills'),
                    'inhibitorTakedowns': participant.get('inhibitorTakedowns'),
                    'inhibitorsLost': participant.get('inhibitorsLost'),
                    'item0': participant.get('item0'),
                    'item1': participant.get('item1'),
                    'item2': participant.get('item2'),
                    'item3': participant.get('item3'),
                    'item4': participant.get('item4'),
                    'item5': participant.get('item5'),
                    'item6': participant.get('item6'),
                    'itemsPurchased': participant.get('itemsPurchased'),
                    'killingSprees': participant.get('killingSprees'),
                    'kills': participant.get('kills'),
                    'lane': participant.get('lane'),
                    'largestCriticalStrike': participant.get('largestCriticalStrike'),
                    'largestKillingSpree': participant.get('largestKillingSpree'),
                    'largestMultiKill': participant.get('largestMultiKill'),
                    'longestTimeSpentLiving': participant.get('longestTimeSpentLiving'),
                    'magicDamageDealt': participant.get('magicDamageDealt'),
                    'magicDamageDealtToChampions': participant.get('magicDamageDealtToChampions'),
                    'magicDamageTaken': participant.get('magicDamageTaken'),
                    'needVisionPings': participant.get('needVisionPings'),
                    'neutralMinionsKilled': participant.get('neutralMinionsKilled'),
                    'nexusKills': participant.get('nexusKills'),
                    'nexusLost': participant.get('nexusLost'),
                    'nexusTakedowns': participant.get('nexusTakedowns'),
                    'objectivesStolen': participant.get('objectivesStolen'),
                    'objectivesStolenAssists': participant.get('objectivesStolenAssists'),
                    'onMyWayPings': participant.get('onMyWayPings'),
                    'participantId': participant.get('participantId'),
                    'pentaKills': participant.get('pentaKills'),
                    'physicalDamageDealt': participant.get('physicalDamageDealt'),
                    'physicalDamageDealtToChampions': participant.get('physicalDamageDealtToChampions'),
                    'physicalDamageTaken': participant.get('physicalDamageTaken'),
                    'profileIcon': participant.get('profileIcon'),
                    'pushPings': participant.get('pushPings'),
                    'quadraKills': participant.get('quadraKills'),
                    'role': participant.get('role'),
                    'sightWardsBoughtInGame': participant.get('sightWardsBoughtInGame'),
                    'spell1Casts': participant.get('spell1Casts'),
                    'spell2Casts': participant.get('spell2Casts'),
                    'spell3Casts': participant.get('spell3Casts'),
                    'spell4Casts': participant.get('spell4Casts'),
                    'summoner1Casts': participant.get('summoner1Casts'),
                    'summoner1Id': participant.get('summoner1Id'),
                    'summoner2Casts': participant.get('summoner2Casts'),
                    'summoner2Id': participant.get('summoner2Id'),
                    'summonerLevel': participant.get('summonerLevel'),
                    'teamEarlySurrendered': participant.get('teamEarlySurrendered'),
                    'teamId': participant.get('teamId'),
                    'teamPosition': participant.get('teamPosition'),
                    'timeCCingOthers': participant.get('timeCCingOthers'),
                    'timePlayed': participant.get('timePlayed'),
                    'totalAllyJungleMinionsKilled': participant.get('totalAllyJungleMinionsKilled'),
                    'totalDamageDealt': participant.get('totalDamageDealt'),
                    'totalDamageDealtToChampions': participant.get('totalDamageDealtToChampions'),
                    'totalDamageShieldedOnTeammates': participant.get('totalDamageShieldedOnTeammates'),
                    'totalDamageTaken': participant.get('totalDamageTaken'),
                    'totalEnemyJungleMinionsKilled': participant.get('totalEnemyJungleMinionsKilled'),
                    'totalHeal': participant.get('totalHeal'),
                    'totalHealsOnTeammates': participant.get('totalHealsOnTeammates'),
                    'totalMinionsKilled': participant.get('totalMinionsKilled'),
                    'totalTimeCCDealt': participant.get('totalTimeCCDealt'),
                    'totalTimeSpentDead': participant.get('totalTimeSpentDead'),
                    'totalUnitsHealed': participant.get('totalUnitsHealed'),
                    'tripleKills': participant.get('tripleKills'),
                    'trueDamageDealt': participant.get('trueDamageDealt'),
                    'trueDamageDealtToChampions': participant.get('trueDamageDealtToChampions'),
                    'trueDamageTaken': participant.get('trueDamageTaken'),
                    'turretKills': participant.get('turretKills'),
                    'turretTakedowns': participant.get('turretTakedowns'),
                    'turretsLost': participant.get('turretsLost'),
                    'unrealKills': participant.get('unrealKills'),
                    'visionClearedPings': participant.get('visionClearedPings'),
                    'visionScore': participant.get('visionScore'),
                    'visionWardsBoughtInGame': participant.get('visionWardsBoughtInGame'),
                    'wardsKilled': participant.get('wardsKilled'),
                    'wardsPlaced': participant.get('wardsPlaced'),
                    'win': participant.get('win'),
                    'allInPings': participant.get('allInPings'),
                    'assistMePings': participant.get('assistMePings'),
                    'assists': participant.get('assists'),
                    'baronKills': participant.get('baronKills'),
                    'basicPings': participant.get('basicPings'),
                    'bountyLevel': participant.get('bountyLevel'),
                    '12AssistStreakCount': participant['challenges'].get('12AssistStreakCount'),
                    'InfernalScalePickup': participant['challenges'].get('InfernalScalePickup'),
                    'SWARM_DefeatAatrox': participant['challenges'].get('SWARM_DefeatAatrox'),
                    'SWARM_DefeatBriar': participant['challenges'].get('SWARM_DefeatBriar'),
                    'SWARM_DefeatMiniBosses': participant['challenges'].get('SWARM_DefeatMiniBosses'),
                    'SWARM_EvolveWeapon': participant['challenges'].get('SWARM_EvolveWeapon'),
                    'SWARM_Have3Passives': participant['challenges'].get('SWARM_Have3Passives'),
                    'SWARM_KillEnemy': participant['challenges'].get('SWARM_KillEnemy'),
                    'SWARM_PickupGold': participant['challenges'].get('SWARM_PickupGold'),
                    'SWARM_ReachLevel50': participant['challenges'].get('SWARM_ReachLevel50'),
                    'SWARM_Survive15Min': participant['challenges'].get('SWARM_Survive15Min'),
                    'SWARM_WinWith5EvolvedWeapons': participant['challenges'].get('SWARM_WinWith5EvolvedWeapons'),
                    'abilityUses': participant['challenges'].get('abilityUses'),
                    'acesBefore15Minutes': participant['challenges'].get('acesBefore15Minutes'),
                    'alliedJungleMonsterKills': participant['challenges'].get('alliedJungleMonsterKills'),
                    'baronTakedowns': participant['challenges'].get('baronTakedowns'),
                    'blastConeOppositeOpponentCount': participant['challenges'].get('blastConeOppositeOpponentCount'),
                    'bountyGold': participant['challenges'].get('bountyGold'),
                    'buffsStolen': participant['challenges'].get('buffsStolen'),
                    'completeSupportQuestInTime': participant['challenges'].get('completeSupportQuestInTime'),
                    'controlWardsPlaced': participant['challenges'].get('controlWardsPlaced'),
                    'damagePerMinute': participant['challenges'].get('damagePerMinute'),
                    'damageTakenOnTeamPercentage': participant['challenges'].get('damageTakenOnTeamPercentage'),
                    'dancedWithRiftHerald': participant['challenges'].get('dancedWithRiftHerald'),
                    'deathsByEnemyChamps': participant['challenges'].get('deathsByEnemyChamps'),
                    'dodgeSkillShotsSmallWindow': participant['challenges'].get('dodgeSkillShotsSmallWindow'),
                    'doubleAces': participant['challenges'].get('doubleAces'),
                    'dragonTakedowns': participant['challenges'].get('dragonTakedowns'),
                    'earlyLaningPhaseGoldExpAdvantage': participant['challenges'].get('earlyLaningPhaseGoldExpAdvantage'),
                    'effectiveHealAndShielding': participant['challenges'].get('effectiveHealAndShielding'),
                    'elderDragonKillsWithOpposingSoul': participant['challenges'].get('elderDragonKillsWithOpposingSoul'),
                    'elderDragonMultikills': participant['challenges'].get('elderDragonMultikills'),
                    'enemyChampionImmobilizations': participant['challenges'].get('enemyChampionImmobilizations'),
                    'enemyJungleMonsterKills': participant['challenges'].get('enemyJungleMonsterKills'),
                    'epicMonsterKillsNearEnemyJungler': participant['challenges'].get('epicMonsterKillsNearEnemyJungler'),
                    'epicMonsterKillsWithin30SecondsOfSpawn': participant['challenges'].get('epicMonsterKillsWithin30SecondsOfSpawn'),
                    'epicMonsterSteals': participant['challenges'].get('epicMonsterSteals'),
                    'epicMonsterStolenWithoutSmite': participant['challenges'].get('epicMonsterStolenWithoutSmite'),
                    'firstTurretKilled': participant['challenges'].get('firstTurretKilled'),
                    'firstTurretKilledTime': participant['challenges'].get('firstTurretKilledTime'),
                    'fistBumpParticipation': participant['challenges'].get('fistBumpParticipation'),
                    'flawlessAces': participant['challenges'].get('flawlessAces'),
                    'fullTeamTakedown': participant['challenges'].get('fullTeamTakedown'),
                    'gameLength': participant['challenges'].get('gameLength'),
                    'getTakedownsInAllLanesEarlyJungleAsLaner': participant['challenges'].get('getTakedownsInAllLanesEarlyJungleAsLaner'),
                    'goldPerMinute': participant['challenges'].get('goldPerMinute'),
                    'hadOpenNexus': participant['challenges'].get('hadOpenNexus'),
                    'immobilizeAndKillWithAlly': participant['challenges'].get('immobilizeAndKillWithAlly'),
                    'initialBuffCount': participant['challenges'].get('initialBuffCount'),
                    'initialCrabCount': participant['challenges'].get('initialCrabCount'),
                    'jungleCsBefore10Minutes': participant['challenges'].get('jungleCsBefore10Minutes'),
                    'junglerTakedownsNearDamagedEpicMonster': participant['challenges'].get('junglerTakedownsNearDamagedEpicMonster'),
                    'kTurretsDestroyedBeforePlatesFall': participant['challenges'].get('kTurretsDestroyedBeforePlatesFall'),
                    'kda': participant['challenges'].get('kda'),
                    'killAfterHiddenWithAlly': participant['challenges'].get('killAfterHiddenWithAlly'),
                    'killParticipation': participant['challenges'].get('killParticipation'),
                    'killedChampTookFullTeamDamageSurvived': participant['challenges'].get('killedChampTookFullTeamDamageSurvived'),
                    'challengeKillingSprees': participant['challenges'].get('killingSprees'),
                    'killsNearEnemyTurret': participant['challenges'].get('killsNearEnemyTurret'),
                    'killsOnOtherLanesEarlyJungleAsLaner': participant['challenges'].get('killsOnOtherLanesEarlyJungleAsLaner'),
                    'killsOnRecentlyHealedByAramPack': participant['challenges'].get('killsOnRecentlyHealedByAramPack'),
                    'killsUnderOwnTurret': participant['challenges'].get('killsUnderOwnTurret'),
                    'killsWithHelpFromEpicMonster': participant['challenges'].get('killsWithHelpFromEpicMonster'),
                    'knockEnemyIntoTeamAndKill': participant['challenges'].get('knockEnemyIntoTeamAndKill'),
                    'landSkillShotsEarlyGame': participant['challenges'].get('landSkillShotsEarlyGame'),
                    'laneMinionsFirst10Minutes': participant['challenges'].get('laneMinionsFirst10Minutes'),
                    'laningPhaseGoldExpAdvantage': participant['challenges'].get('laningPhaseGoldExpAdvantage'),
                    'legendaryCount': participant['challenges'].get('legendaryCount'),
                    'legendaryItemUsed': participant['challenges'].get('legendaryItemUsed'),
                    'lostAnInhibitor': participant['challenges'].get('lostAnInhibitor'),
                    'maxCsAdvantageOnLaneOpponent': participant['challenges'].get('maxCsAdvantageOnLaneOpponent'),
                    'maxKillDeficit': participant['challenges'].get('maxKillDeficit'),
                    'maxLevelLeadLaneOpponent': participant['challenges'].get('maxLevelLeadLaneOpponent'),
                    'mejaisFullStackInTime': participant['challenges'].get('mejaisFullStackInTime'),
                    'moreEnemyJungleThanOpponent': participant['challenges'].get('moreEnemyJungleThanOpponent'),
                    'multiKillOneSpell': participant['challenges'].get('multiKillOneSpell'),
                    'multiTurretRiftHeraldCount': participant['challenges'].get('multiTurretRiftHeraldCount'),
                    'multikills': participant['challenges'].get('multikills'),
                    'multikillsAfterAggressiveFlash': participant['challenges'].get('multikillsAfterAggressiveFlash'),
                    'outerTurretExecutesBefore10Minutes': participant['challenges'].get('outerTurretExecutesBefore10Minutes'),
                    'outnumberedKills': participant['challenges'].get('outnumberedKills'),
                    'outnumberedNexusKill': participant['challenges'].get('outnumberedNexusKill'),
                    'perfectDragonSoulsTaken': participant['challenges'].get('perfectDragonSoulsTaken'),
                    'perfectGame': participant['challenges'].get('perfectGame'),
                    'pickKillWithAlly': participant['challenges'].get('pickKillWithAlly'),
                    'playedChampSelectPosition': participant['challenges'].get('playedChampSelectPosition'),
                    'poroExplosions': participant['challenges'].get('poroExplosions'),
                    'quickCleanse': participant['challenges'].get('quickCleanse'),
                    'quickFirstTurret': participant['challenges'].get('quickFirstTurret'),
                    'quickSoloKills': participant['challenges'].get('quickSoloKills'),
                    'riftHeraldTakedowns': participant['challenges'].get('riftHeraldTakedowns'),
                    'saveAllyFromDeath': participant['challenges'].get('saveAllyFromDeath'),
                    'scuttleCrabKills': participant['challenges'].get('scuttleCrabKills'),
                    'skillshotsDodged': participant['challenges'].get('skillshotsDodged'),
                    'skillshotsHit': participant['challenges'].get('skillshotsHit'),
                    'snowballsHit': participant['challenges'].get('snowballsHit'),
                    'soloBaronKills': participant['challenges'].get('soloBaronKills'),
                    'soloKills': participant['challenges'].get('soloKills'),
                    'stealthWardsPlaced': participant['challenges'].get('stealthWardsPlaced'),
                    'survivedSingleDigitHpCount': participant['challenges'].get('survivedSingleDigitHpCount'),
                    'survivedThreeImmobilizesInFight': participant['challenges'].get('survivedThreeImmobilizesInFight'),
                    'takedownOnFirstTurret': participant['challenges'].get('takedownOnFirstTurret'),
                    'takedowns': participant['challenges'].get('takedowns'),
                    'takedownsAfterGainingLevelAdvantage': participant['challenges'].get('takedownsAfterGainingLevelAdvantage'),
                    'takedownsBeforeJungleMinionSpawn': participant['challenges'].get('takedownsBeforeJungleMinionSpawn'),
                    'takedownsFirstXMinutes': participant['challenges'].get('takedownsFirstXMinutes'),
                    'takedownsInAlcove': participant['challenges'].get('takedownsInAlcove'),
                    'takedownsInEnemyFountain': participant['challenges'].get('takedownsInEnemyFountain'),
                    'teamBaronKills': participant['challenges'].get('teamBaronKills'),
                    'teamDamagePercentage': participant['challenges'].get('teamDamagePercentage'),
                    'teamElderDragonKills': participant['challenges'].get('teamElderDragonKills'),
                    'teamRiftHeraldKills': participant['challenges'].get('teamRiftHeraldKills'),
                    'tookLargeDamageSurvived': participant['challenges'].get('tookLargeDamageSurvived'),
                    'turretPlatesTaken': participant['challenges'].get('turretPlatesTaken'),
                    'challengeTurretTakedowns': participant['challenges'].get('turretTakedowns'),
                    'turretsTakenWithRiftHerald': participant['challenges'].get('turretsTakenWithRiftHerald'),
                    'twentyMinionsIn3SecondsCount': participant['challenges'].get('twentyMinionsIn3SecondsCount'),
                    'twoWardsOneSweeperCount': participant['challenges'].get('twoWardsOneSweeperCount'),
                    'unseenRecalls': participant['challenges'].get('unseenRecalls'),
                    'visionScoreAdvantageLaneOpponent': participant['challenges'].get('visionScoreAdvantageLaneOpponent'),
                    'visionScorePerMinute': participant['challenges'].get('visionScorePerMinute'),
                    'voidMonsterKill': participant['challenges'].get('voidMonsterKill'),
                    'wardTakedowns': participant['challenges'].get('wardTakedowns'),
                    'wardTakedownsBefore20M': participant['challenges'].get('wardTakedownsBefore20M'),
                    'wardsGuarded': participant['challenges'].get('wardsGuarded'),
                }
    except json.JSONDecodeError:
        return None

# data와 meta_df를 결합하여 summonerId를 기준으로 데이터 추출
def get_filtered_data(data, meta_df):
    filtered_data = []
    for index, row in meta_df.iterrows():
        summoner_id = data.loc[index, 'summonerId']
        participant_data = extract_participant_data(row, summoner_id)
        filtered_data.append(participant_data)
    return pd.DataFrame(filtered_data)

# 결과 확인
filtered_df = get_filtered_data(data, meta_df)
print(filtered_df)
# Out:
#       champExperience  champLevel  championId championName  championTransform  \
# 0               12132          14         120      Hecarim                  0
# 1               11344          13         113      Sejuani                  0
# 2               10724          13         120      Hecarim                  0
# 3                   0           1         245         Ekko                  0
# 4               17455          17         120      Hecarim                  0
# ...               ...         ...         ...          ...                ...
# 2455             6478          10          56     Nocturne                  0
# 2456            16351          16         421       RekSai                  0
# 2457            11369          13         102      Shyvana                  0
# 2458             8663          12          58     Renekton                  0
# 2459            18448          18          82  Mordekaiser                  0
#
#       commandPings  consumablesPurchased  damageDealtToBuildings  \
# 0                4                     6                    2417
# 1                5                     5                    2965
# 2                9                     5                       0
# 3                0                     1                       0
# 4                5                     6                    5893
# ...            ...                   ...                     ...
# 2455             0                     3                       0
# 2456             0                     3                       0
# 2457             1                     3                       0
# 2458             0                     2                     797
# 2459             0                     3                    1665
#
#       damageDealtToObjectives  damageDealtToTurrets  ...  \
# 0                       24379                  2417  ...
# 1                       25510                  2965  ...
# 2                        2490                     0  ...
# 3                           0                     0  ...
# 4                       52575                  5893  ...
# ...                       ...                   ...  ...
# 2455                    24864                     0  ...
# 2456                    33590                     0  ...
# 2457                    29276                     0  ...
# 2458                      797                   797  ...
# 2459                     1989                  1665  ...
#
#       turretsTakenWithRiftHerald  twentyMinionsIn3SecondsCount  \
# 0                              5                             0
# 1                              5                             0
# 2                              0                             0
# 3                              0                             0
# 4                              5                             0
# ...                          ...                           ...
# 2455                           0                             0
# 2456                           0                             0
# 2457                           0                             0
# 2458                           0                             0
# 2459                           0                             0
#
#       twoWardsOneSweeperCount  unseenRecalls  \
# 0                           0              0
# 1                           1              0
# 2                           2              0
# 3                           0              0
# 4                           0              0
# ...                       ...            ...
# 2455                        0              0
# 2456                        0              0
# 2457                        0              0
# 2458                        0              0
# 2459                        0              0
#
#       visionScoreAdvantageLaneOpponent  visionScorePerMinute  voidMonsterKill  \
# 0                             0.206416              0.976880                4
# 1                            -0.248859              0.754450                4
# 2                            -0.026729              0.824245                0
# 3                                  NaN              0.000000                0
# 4                             1.487363              1.131205                8
# ...                                ...                   ...              ...
# 2455                          0.587558              0.892765                2
# 2456                         -0.350068              0.542493                1
# 2457                         -0.051132              0.655438                6
# 2458                          1.396507              1.010967                0
# 2459                          1.064834              0.812533                1
#
#       wardTakedowns  wardTakedownsBefore20M  wardsGuarded
# 0                 2                       1             1
# 1                 3                       2             0
# 2                 3                       1             1
# 3                 0                       0             0
# 4                 4                       4             2
# ...             ...                     ...           ...
# 2455              2                       2             0
# 2456              0                       0             0
# 2457              4                       3             0
# 2458              2                       2             0
# 2459              1                       1             0
#
# [2460 rows x 240 columns]

# %%
## killingSprees, turretTakedowns 두 변수명이 중복된다.
## 하나는 participant안에, 나머지 하나는 participant['challenges'] 안에 존재한다.
## 아마도 participant['challenges']는 특정 시간, 기간 등 도전의 성격으로 기록의 관점 차이가 있는 것 같다.
## 따라서, 두 변수에만 받아올 변수명에 challenges를 붙여두었다.
len(filtered_df.columns)
# Out:
# 240

# %%
filtered_df = pd.DataFrame(filtered_df)
filtered_df
# Out:
#       champExperience  champLevel  championId championName  championTransform  \
# 0               12132          14         120      Hecarim                  0
# 1               11344          13         113      Sejuani                  0
# 2               10724          13         120      Hecarim                  0
# 3                   0           1         245         Ekko                  0
# 4               17455          17         120      Hecarim                  0
# ...               ...         ...         ...          ...                ...
# 2455             6478          10          56     Nocturne                  0
# 2456            16351          16         421       RekSai                  0
# 2457            11369          13         102      Shyvana                  0
# 2458             8663          12          58     Renekton                  0
# 2459            18448          18          82  Mordekaiser                  0
#
#       commandPings  consumablesPurchased  damageDealtToBuildings  \
# 0                4                     6                    2417
# 1                5                     5                    2965
# 2                9                     5                       0
# 3                0                     1                       0
# 4                5                     6                    5893
# ...            ...                   ...                     ...
# 2455             0                     3                       0
# 2456             0                     3                       0
# 2457             1                     3                       0
# 2458             0                     2                     797
# 2459             0                     3                    1665
#
#       damageDealtToObjectives  damageDealtToTurrets  ...  \
# 0                       24379                  2417  ...
# 1                       25510                  2965  ...
# 2                        2490                     0  ...
# 3                           0                     0  ...
# 4                       52575                  5893  ...
# ...                       ...                   ...  ...
# 2455                    24864                     0  ...
# 2456                    33590                     0  ...
# 2457                    29276                     0  ...
# 2458                      797                   797  ...
# 2459                     1989                  1665  ...
#
#       turretsTakenWithRiftHerald  twentyMinionsIn3SecondsCount  \
# 0                              5                             0
# 1                              5                             0
# 2                              0                             0
# 3                              0                             0
# 4                              5                             0
# ...                          ...                           ...
# 2455                           0                             0
# 2456                           0                             0
# 2457                           0                             0
# 2458                           0                             0
# 2459                           0                             0
#
#       twoWardsOneSweeperCount  unseenRecalls  \
# 0                           0              0
# 1                           1              0
# 2                           2              0
# 3                           0              0
# 4                           0              0
# ...                       ...            ...
# 2455                        0              0
# 2456                        0              0
# 2457                        0              0
# 2458                        0              0
# 2459                        0              0
#
#       visionScoreAdvantageLaneOpponent  visionScorePerMinute  voidMonsterKill  \
# 0                             0.206416              0.976880                4
# 1                            -0.248859              0.754450                4
# 2                            -0.026729              0.824245                0
# 3                                  NaN              0.000000                0
# 4                             1.487363              1.131205                8
# ...                                ...                   ...              ...
# 2455                          0.587558              0.892765                2
# 2456                         -0.350068              0.542493                1
# 2457                         -0.051132              0.655438                6
# 2458                          1.396507              1.010967                0
# 2459                          1.064834              0.812533                1
#
#       wardTakedowns  wardTakedownsBefore20M  wardsGuarded
# 0                 2                       1             1
# 1                 3                       2             0
# 2                 3                       1             1
# 3                 0                       0             0
# 4                 4                       4             2
# ...             ...                     ...           ...
# 2455              2                       2             0
# 2456              0                       0             0
# 2457              4                       3             0
# 2458              2                       2             0
# 2459              1                       1             0
#
# [2460 rows x 240 columns]

# %%
# MSE,RMSE는 특이값을 직관적으로 반영함. 큰 오차가 작은 오차보다 더 큰 영향을 끼침.
# MAE,MAPE는 특이값을 동등하게 반영함. 오차가 동일한 영향력을 행사.

# %%
data.head()
# Out:
#                                          summonerId    tier rank  \
# 0  P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 1  P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 2  P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 3  P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
# 4  P8Zm5FFZK0wgSP__V3Dqpzz2onPMednYDYbfr3uxDD_f-WK3  BRONZE    I
#
#    leaguePoints  wins  losses   winRatio  \
# 0            19    80      77  50.955414
# 1            19    80      77  50.955414
# 2            19    80      77  50.955414
# 3            19    80      77  50.955414
# 4            19    80      77  50.955414
#
#                                                puuid        matchid  \
# 0  0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7159555521
# 1  0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7148630418
# 2  0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7148576264
# 3  0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7148570014
# 4  0hC5lHI9FtdR6rfc-aEajC2BPvinRYWW2XOcWpigs-6idG...  KR_7142285759
#
#                                        metadata_json
# 0  {"metadata": {"dataVersion": "2", "matchId": "...
# 1  {"metadata": {"dataVersion": "2", "matchId": "...
# 2  {"metadata": {"dataVersion": "2", "matchId": "...
# 3  {"metadata": {"dataVersion": "2", "matchId": "...
# 4  {"metadata": {"dataVersion": "2", "matchId": "...

# %%
game_data = pd.concat([data['tier'],data['rank'],data['leaguePoints'],filtered_df],axis=1)
game_data
# Out:
#         tier rank  leaguePoints  champExperience  champLevel  championId  \
# 0     BRONZE    I            19            12132          14         120
# 1     BRONZE    I            19            11344          13         113
# 2     BRONZE    I            19            10724          13         120
# 3     BRONZE    I            19                0           1         245
# 4     BRONZE    I            19            17455          17         120
# ...      ...  ...           ...              ...         ...         ...
# 2455  BRONZE    I            46             6478          10          56
# 2456  BRONZE    I            46            16351          16         421
# 2457  BRONZE    I            46            11369          13         102
# 2458  BRONZE    I            46             8663          12          58
# 2459  BRONZE    I            46            18448          18          82
#
#      championName  championTransform  commandPings  consumablesPurchased  ...  \
# 0         Hecarim                  0             4                     6  ...
# 1         Sejuani                  0             5                     5  ...
# 2         Hecarim                  0             9                     5  ...
# 3            Ekko                  0             0                     1  ...
# 4         Hecarim                  0             5                     6  ...
# ...           ...                ...           ...                   ...  ...
# 2455     Nocturne                  0             0                     3  ...
# 2456       RekSai                  0             0                     3  ...
# 2457      Shyvana                  0             1                     3  ...
# 2458     Renekton                  0             0                     2  ...
# 2459  Mordekaiser                  0             0                     3  ...
#
#       turretsTakenWithRiftHerald  twentyMinionsIn3SecondsCount  \
# 0                              5                             0
# 1                              5                             0
# 2                              0                             0
# 3                              0                             0
# 4                              5                             0
# ...                          ...                           ...
# 2455                           0                             0
# 2456                           0                             0
# 2457                           0                             0
# 2458                           0                             0
# 2459                           0                             0
#
#       twoWardsOneSweeperCount  unseenRecalls  \
# 0                           0              0
# 1                           1              0
# 2                           2              0
# 3                           0              0
# 4                           0              0
# ...                       ...            ...
# 2455                        0              0
# 2456                        0              0
# 2457                        0              0
# 2458                        0              0
# 2459                        0              0
#
#       visionScoreAdvantageLaneOpponent  visionScorePerMinute  voidMonsterKill  \
# 0                             0.206416              0.976880                4
# 1                            -0.248859              0.754450                4
# 2                            -0.026729              0.824245                0
# 3                                  NaN              0.000000                0
# 4                             1.487363              1.131205                8
# ...                                ...                   ...              ...
# 2455                          0.587558              0.892765                2
# 2456                         -0.350068              0.542493                1
# 2457                         -0.051132              0.655438                6
# 2458                          1.396507              1.010967                0
# 2459                          1.064834              0.812533                1
#
#       wardTakedowns  wardTakedownsBefore20M  wardsGuarded
# 0                 2                       1             1
# 1                 3                       2             0
# 2                 3                       1             1
# 3                 0                       0             0
# 4                 4                       4             2
# ...             ...                     ...           ...
# 2455              2                       2             0
# 2456              0                       0             0
# 2457              4                       3             0
# 2458              2                       2             0
# 2459              1                       1             0
#
# [2460 rows x 243 columns]

# %%
# 티어별 데이터를 전부 모은 뒤, concat 후 해당 함수로 변수 추출할 예정
